# %%
## Q.1.
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df_wine = pd.read_csv("1.0-winequality-red.csv")

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.heatmap(df_wine.corr(), annot = True)
# Out:
# <AxesSubplot: >

# %%
## Free sulpher dioxide and Total sulpher dioxide are highly correlated, hence one of them is they are redundant.
## Citric acid and fixed acidity are highly correlated.
## density and fixed acidity are highly correlated.
## pH and fixed acidity are highly -vely correlated.
## alcohol and density are highly -vely correlated.
## citric acid and pH are  highly -vely correlated.
## citric acid and volatile acidity are highly -vely correlated.
"""Hence key features are Free sulpher dioxide, Fixed acidity, Volatile Acidity , Alcohol, Residual Sugar and Chlorides.
Important features in predicting quality of wine are:-
1. Free sulpher dioxide
2. Fixed acidity
3. Residual Sugar
4. Chlorides
5. density 
"""
# Out:
# 'Hence key features are Free sulpher dioxide, Fixed acidity, Volatile Acidity , Alcohol, Residual Sugar and Chlorides.\nImportant features in predicting quality of wine are:-\n1. Free sulpher dioxide\n2. Fixed acidity\n3. Residual Sugar\n4. Chlorides\n5. density \n'

# %%
##Q.2.
df_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
"""There are no missing data in the wine-quality dataset.
If there would have been any missing data I would have handled by imputing mean for particular column.
There are various ways for imputaion-:
1. Imputation by mean for numerical data.
2. Imputaion by mode for categorical data.
3. Imputaion by median for numerical data.
4. Interpolation.
"""
# Out:
# 'There are no missing data in the wine-quality dataset.\nIf there would have been any missing data I would have handled by imputing mean for particular column.\nThere are various ways for imputaion-:\n1. Imputation by mean for numerical data.\n2. Imputaion by mode for categorical data.\n3. Imputaion by median for numerical data.\n4. Interpolation.\n'

# %%
"""Advantage of Data Imputaion techniques:
1. It fills the missing values instead of deleting them which can decrease accuracy.
2. It improves accuracy, precision and recall as commpared to row wise, column wise and pair wise deletion.
3. It improves interpretability
4. Imputation is a practical and simple solution for handling missing values."""
# Out:
# 'Advantage of Data Imputaion techniques:\n1. It fills the missing values instead of deleting them which can decrease accuracy.\n2. It improves accuracy, precision and recall as commpared to row wise, column wise and pair wise deletion.\n3. It improves interpretability\n4. Imputation is a practical and simple solution for handling missing values.'

# %%
"""Disadvantage of Data Imputaion techniques:
1. In case of outliers in dataset, it imputes central tendecy values directly without noting the range in which that central tendency value
falls into.
2. It can further decrease model performance.
3. It doesn't work for larger datasets with 1000 attributes.
"""
# Out:
# "Disadvantage of Data Imputaion techniques:\n1. In case of outliers in dataset, it imputes central tendecy values directly without noting the range in which that central tendency value\nfalls into.\n2. It can further decrease model performance.\n3. It doesn't work for larger datasets with 1000 attributes.\n"

# %%
"""Q.3."""
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings 
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("stud.csv")

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['Total_marks'] = df['math_score'] + df['reading_score'] +df['writing_score']
df['Average_marks'] = df['Total_marks']/3

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total_marks  Average_marks
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# Total_marks                    0
# Average_marks                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
#  8   Total_marks                  1000 non-null   int64
#  9   Average_marks                1000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 78.2+ KB

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score  Total_marks  Average_marks
# count  1000.00000    1000.000000    1000.000000  1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000   203.312000      67.770667
# std      15.16308      14.600192      15.195657    42.771978      14.257326
# min       0.00000      17.000000      10.000000    27.000000       9.000000
# 25%      57.00000      59.000000      57.750000   175.000000      58.333333
# 50%      66.00000      70.000000      69.000000   205.000000      68.333333
# 75%      77.00000      79.000000      79.000000   233.000000      77.666667
# max     100.00000     100.000000     100.000000   300.000000     100.000000

# %%
df.nunique()
# Out:
# gender                           2
# race_ethnicity                   5
# parental_level_of_education      6
# lunch                            2
# test_preparation_course          2
# math_score                      81
# reading_score                   72
# writing_score                   77
# Total_marks                    194
# Average_marks                  194
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
encoded = encoder.fit_transform(df["gender"])

# %%
df["gender_encoded"] = encoded

# %%
encoded_race_ethnicity = encoder.fit_transform(df["race_ethnicity"])

# %%
df["encoded_race_ethnicity"] = encoded_race_ethnicity

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder = OrdinalEncoder(categories = [["master's degree", "bachelor's degree", "associate's degree" ,"some college", "high school", "some high school"]])

# %%
encoded = encoder.fit_transform(df[["parental_level_of_education"]])

# %%
df["parental_level_of_education_encoded"] = encoded

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder_1 = OrdinalEncoder(categories = [["standard","free/reduced"]])

# %%
encoded_lunch = encoder_1.fit_transform(df[["lunch"]])

# %%
df["lunch_encoded"] = encoded_lunch

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total_marks  Average_marks  gender_encoded  encoded_race_ethnicity  \
# 0          218      72.666667               0                       1
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
plt.subplots(1,4,figsize = (25,15))
plt.subplot(141)
sns.histplot(data = df, x = df['Average_marks'], hue = df['race_ethnicity'], kde = True)
plt.subplot(142)
sns.histplot(data = df, x = df['Average_marks'], hue = df['parental_level_of_education'], kde = True)
plt.subplot(143)
sns.histplot(data = df, x = df['Average_marks'], hue = df['lunch'], kde = True)
plt.subplot(144)
sns.histplot(data = df, x = df['Average_marks'], hue = df['gender'], kde = True)
# Out:
# <AxesSubplot: xlabel='Average_marks', ylabel='Count'>

# %%
"""
1. Parental level of education doesn't helps students perform better in exam.
2. Female students tend to perform better
3. Students belonging to race C, D and E have performed better
4. Standard lunch helps students perform better in exam.
"""
# Out:
# "\n1. Parental level of education doesn't helps students perform better in exam.\n2. Female students tend to perform better\n3. Students belonging to race C, D and E have performed better\n4. Standard lunch helps students perform better in exam.\n"

# %%
"""Statistical Analysis-
All the average score is between 66 to 70.
All the standard deviation is between 14 to 16.
Maximum score scored by students has been highest.
Lowest score in maths is zero, while in other subjects it is not so.
"""
# Out:
# 'Statistical Analysis-\nAll the average score is between 66 to 70.\nAll the standard deviation is between 14 to 16.\nMaximum score scored by students has been highest.\nLowest score in maths is zero, while in other subjects it is not so.\n'

# %%
"""Q.4. I used label encoding and ordinal encoding to encode nominal and ordinal attributes to numerical attributes.
Then i used correlation to find the correlation between different attributes and their dependency. In that wway we can delete one redundant attribute.
"""
# Out:
# 'Q.4. I used label encoding and ordinal encoding to encode nominal and ordinal attributes to numerical attributes.\nThen i used correlation to find the correlation between different attributes and their dependency. In that wway we can delete one redundant attribute.\n'

# %%
"""Q.5."""
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df_wine = pd.read_csv("1.0-winequality-red.csv")

# %%
df_wine.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
plt.subplots(1,3,figsize=(15,7))
plt.subplot(131)
plt.title("Fixed_acidity_plot")
sns.histplot(data = df_wine, x = df_wine["fixed acidity"],kde = True)
plt.subplot(132)
plt.title("Volatile_acidity_plot")
sns.histplot(data = df_wine, x = df_wine["volatile acidity"],kde = True)
plt.subplot(133)
plt.title("Citric_acidity_plot")
sns.histplot(data = df_wine, x = df_wine["citric acid"],kde = True)
# Out:
# <AxesSubplot: title={'center': 'Citric_acidity_plot'}, xlabel='citric acid', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(15,7))
plt.subplot(131)
plt.title("Residual_Sugar_plot")
sns.histplot(data = df_wine, x = df_wine["residual sugar"],kde = True)
plt.subplot(132)
plt.title("Chlorides_plot")
sns.histplot(data = df_wine, x = df_wine["chlorides"],kde = True)
plt.subplot(133)
plt.title("Free_Sulpher_Dioxide_plot")
sns.histplot(data = df_wine, x = df_wine["free sulfur dioxide"],kde = True)
# Out:
# <AxesSubplot: title={'center': 'Free_Sulpher_Dioxide_plot'}, xlabel='free sulfur dioxide', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(15,7))
plt.subplot(131)
plt.title("Total_Sulfur_plot")
sns.histplot(data = df_wine, x = df_wine["total sulfur dioxide"],kde = True)
plt.subplot(132)
plt.title("Density_plot")
sns.histplot(data = df_wine, x = df_wine["density"],kde = True)
plt.subplot(133)
plt.title("pH_plot")
sns.histplot(data = df_wine, x = df_wine["pH"],kde = True)
# Out:
# <AxesSubplot: title={'center': 'pH_plot'}, xlabel='pH', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(15,7))
plt.subplot(131)
plt.title("sulphates")
sns.histplot(data = df_wine, x = df_wine["sulphates"],kde = True)
plt.subplot(132)
plt.title("Alcohol_plot")
sns.histplot(data = df_wine, x = df_wine["alcohol"],kde = True)
plt.subplot(133)
plt.title("quality_plot")
sns.histplot(data = df_wine, x = df_wine["quality"],kde = True)

# %%
""" Normal Distribution curves are:-
1. Alcohol
2. Quality
3. Free sulfer dioxide
4. Total sulfer dioxide
5. Volatile acidity
6. Citric acid
"""

# %%
"""Normalization - Min/Max Normalization, Unit Vector Normalization and Mean Normalization"""

# %%
"""Q.6."""
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 5)

# %%
pca.fit(X=df_wine)
# Out:
# PCA(n_components=5)

# %%
arr = pca.explained_variance_ratio_

# %%
arr
# Out:
# array([0.94607951, 0.04834835, 0.00259599, 0.00152289, 0.0010491 ])

# %%
count = 0
for i in range(len(arr)):
    if arr[i] > 0.90:
        count+=1
print("Number of principal components required to explain 90% of the variance:",count)
# Out:
# Number of principal components required to explain 90% of the variance: 1

# %%
import numpy as np
# Calculate the cumulative explained variance ratio
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# Find the index where the cumulative explained variance exceeds 90%
num_components = np.argmax(cumulative_variance_ratio >= 0.90) + 1

print("Number of principal components required to explain 90% of the variance:", num_components)
# Out:
# Number of principal components required to explain 90% of the variance: 1

# %%
pca.singular_values_
# Out:
# array([1346.05255997,  304.29093596,   70.50984811,   54.00475581,
#          44.82367681])
